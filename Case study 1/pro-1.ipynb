# %%
import pandas as pd

# %%
data = pd.read_csv("Ecommerce_Purchases.csv")
data.head()

# %% [markdown]
# TOP 10 ROWS OF THE DATASET

# %%
data.head(10)

# %% [markdown]
# TOP 10 ROWS FROM BOTTOM

# %%
data.tail(10)

# %% [markdown]
# CHECK DATA TYPE OF EACH COLUMN

# %%
data.dtypes

# %% [markdown]
# CHECK NULL VALUES

# %%
data.isnull()

# %% [markdown]
# TOTAL ROWS AND COLUMNS IN THE DATA SET

# %%
len(data.columns)

# %%
len(data)

# %%
data.info()

# %% [markdown]
# HIGHEST AND THE LOWEST PURCHASE

# %%
data["Purchase Price"].max()

# %%
data["Purchase Price"].min()

# %% [markdown]
# AVERAGE PURCHASE

# %%
data['Purchase Price'].mean()

# %% [markdown]
# PEOPLE HAVING FRENCH AS THEIR LANGUAGE

# %%
lang = data[data["Language"] == 'fr']
lang

# %%
len(lang)

# %% [markdown]
# JOB TITLE IS ENGINEER

# %%
job = data[data["Job"].str.contains("Engineer", case = False)]
job

# %%
len(job)

# %% [markdown]
# FIND THE EMAIL WITH IP ADDRESS 132.207.160.22

# %%
data[data["IP Address"] == "132.207.160.22"]["Email"]

# %% [markdown]
# how many people have mastercard as their credit card provider and made a purchase above 50

# %%
data[(data["Purchase Price"] > 50) & (data["CC Provider"] == "Mastercard")]

# %% [markdown]
# find the email of the person with the credit card number: 4664825258997302

# %%
data[data["Credit Card"] == 4664825258997302]["Email"]

# %% [markdown]
# HOW MANY PURCHASE DURING AM AND HOW MANY DURING PM

# %%
AM = data[data["AM or PM"] == "AM"]
AM

# %%
PM = data[data["AM or PM"]== "PM"]
PM

# %% [markdown]
# HOW MANY PEOPLE HAVE CREDIT CARD EXPIRING IN 2020

# %%
exp = data[data["CC Exp Date"].str[3:] =='20']
len(exp)

# %% [markdown]
# TOP 5 MOST POPULAR EMAIL PROVIDERS

# %%
domain = data["Email"].str.split("@").str[1].value_counts().head(5)
domain
